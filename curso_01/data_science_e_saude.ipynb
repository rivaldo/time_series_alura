# %%
import pandas as pd

confirmed = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
confirmed.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  1/14/23  1/15/23  1/16/23  \
# 0        0        0        0        0  ...   207900   207900   207993
# 1        0        0        0        0  ...   334029   334037   334037
# 2        0        0        0        0  ...   271287   271287   271287
# 3        0        0        0        0  ...    47781    47781    47781
# 4        0        0        0        0  ...   105095   105095   105095
#
#    1/17/23  1/18/23  1/19/23  1/20/23  1/21/23  1/22/23  1/23/23
# ...

# %%
confirmed.shape
# Out:
# (289, 1102)

# %%
confirmed['Country/Region']
# Out:
# 0               Afghanistan
# 1                   Albania
# 2                   Algeria
# 3                   Andorra
# 4                    Angola
#                ...
# 284      West Bank and Gaza
# 285    Winter Olympics 2022
# 286                   Yemen
# 287                  Zambia
# 288                Zimbabwe
# Name: Country/Region, Length: 289, dtype: object

# %%
confirmed.dtypes
# Out:
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# 1/22/20             int64
#                    ...
# 1/19/23             int64
# 1/20/23             int64
# 1/21/23             int64
# 1/22/23             int64
# 1/23/23             int64
# Length: 1102, dtype: object

# %%
confirmed['Country/Region'].value_counts()
# Out:
# China             34
# Canada            16
# United Kingdom    15
# France            12
# Australia          8
#                   ..
# Guinea             1
# Guinea-Bissau      1
# Guyana             1
# Haiti              1
# Zimbabwe           1
# Name: Country/Region, Length: 201, dtype: int64

# %%
confirmed.iloc[0]
# Out:
# Province/State            NaN
# Country/Region    Afghanistan
# Lat                  33.93911
# Long                67.709953
# 1/22/20                     0
#                      ...
# 1/19/23                208062
# 1/20/23                208084
# 1/21/23                208084
# 1/22/23                208084
# 1/23/23                208097
# Name: 0, Length: 1102, dtype: object

# %%
confirmed.set_index('Province/State')
# Out:
#                       Country/Region        Lat        Long  1/22/20  1/23/20  \
# Province/State
# NaN                      Afghanistan  33.939110   67.709953        0        0
# NaN                          Albania  41.153300   20.168300        0        0
# NaN                          Algeria  28.033900    1.659600        0        0
# NaN                          Andorra  42.506300    1.521800        0        0
# NaN                           Angola -11.202700   17.873900        0        0
# ...                              ...        ...         ...      ...      ...
# NaN               West Bank and Gaza  31.952200   35.233200        0        0
# NaN             Winter Olympics 2022  39.904200  116.407400        0        0
# NaN                            Yemen  15.552727   48.516388        0        0
# NaN                           Zambia -13.133897   27.849332        0        0
# NaN                         Zimbabwe -19.015438   29.154857        0        0
#
# ...

# %%
confirmed.set_index('Country/Region').loc['Brazil']
# Out:
# Province/State         NaN
# Lat                -14.235
# Long              -51.9253
# 1/22/20                  0
# 1/23/20                  0
#                     ...
# 1/19/23           36677844
# 1/20/23           36712851
# 1/21/23           36717501
# 1/22/23           36718053
# 1/23/23           36730913
# Name: Brazil, Length: 1101, dtype: object

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,6))
confirmed.set_index('Country/Region').loc['Brazil'][3:].plot()
plt.title('Casos confirmados de COVID-19 no Brasil')
plt.xlabel('Período do estudo')
plt.ylabel('Número de casos')
plt = plt.show()

# %%
confirmed.set_index('Country/Region').loc['Brazil'][3:].diff().plot()
# Out:
# <AxesSubplot:>

# %%
confirmed.set_index('1/23/23')[:10].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='1/23/23'>
# Error in callback <function flush_figures at 0x00000165DCD3CAF0> (for post_execute):

# %%
confirmed.set_index('1/23/23')
